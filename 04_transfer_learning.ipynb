# %% [markdown]
# # Tuning a Pretrained Model
#
#  Notebook is self assignment and briefly contain important material for
# implementation itself. The worked solution lives in
# `04_transfer_learning_keras.ipynb`, which:
#
# 1. loads a folder of labeled images,
# 2. takes a model pretrained on ImageNet (Xception),
# 3. replaces its final layer and trains only that new layer
#    ("transfer learning"),
# 4. then unfreezes the whole model and trains a little more with a very
#    small learning rate ("fine-tuning"),
# 5. and finally evaluates the result with a confusion matrix and example
#    predictions.
#
# For the task:It take a model that was trained to classify images and transfer
# that model to make predictions for different classes. The lecture gives the idea of
# this approach while watching the lecture content below.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("IPBSB1HLNLo")

# %% [markdown]
# That video is part of [fast.ai's course *Deep Learning for Coders* from the earlier year
# 2018](https://course18.fast.ai/).
#
# It can choosen any library for doing the transfer learning. Besides
# [fastai](https://docs.fast.ai/), which is covered in the lecture above,
# other common options are [PyTorch](https://pytorch.org/) and
# [TensorFlow](https://www.tensorflow.org/) (used in this repo's solution
# notebook).
#
# Both Keras and PyTorch provide their own transfer-learning tutorials:
# - https://keras.io/guides/transfer_learning/
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
